# %%
import torch

# %% [markdown]
# ![Imagen Tensores.png](data:image/png;base64,...)

# %%
A = torch.randn((8,3,5))

# %%
A.size()
# Out:
# torch.Size([8, 3, 5])

# %%
A.size()==(8,3,5)
# Out:
# True

# %%
A [:,:,:]
# Out:
# tensor([[[ 0.9870,  0.3438, -0.5623, -1.1100, -2.1375],
#          [-1.4481,  1.4822, -0.0690,  0.7827, -2.2322],
#          [-0.8620,  0.3264, -1.4579,  0.5536,  0.9933]],
#
#         [[-0.2215,  3.0913, -1.1374,  0.5196,  1.5083],
#          [ 1.3266,  1.5923,  0.0047, -0.2314, -2.0963],
#          [ 1.0835, -1.7668,  0.1781,  0.7914,  0.0039]],
#
#         [[-0.8441,  1.3362,  1.4454, -0.0962, -1.9268],
#          [ 0.0146, -1.0178,  0.3153, -1.8614,  0.6226],
#          [-2.1542, -0.2019, -0.7823, -1.6565,  0.0075]],
#
#         [[ 1.0782,  0.2161, -0.2789, -0.5563, -0.7682],
#          [ 0.1405,  1.7170, -1.3356,  0.0311,  0.0394],
#          [-0.1262, -1.3870, -1.2780, -0.5302, -1.7480]],
#
#         [[ 0.2534,  0.1945, -0.1871,  0.1255,  0.1142],
#          [ 1.2228,  2.4626, -1.1439,  1.5624,  1.4500],
#          [ 0.5545,  1.6141,  0.1621, -0.7161, -0.1675]],
#
#         [[-0.3556, -0.5271, -0.7001, -1.4440,  1.9751],
# ...

# %%
A[0,0,0]
# Out:
# tensor(-0.2547)

# %%
C = torch.zeros((5,5))

# %%
C.dtype
# Out:
# torch.float32

# %%
## ver si los tensores osn compatibles
D = torch.randint(2,(5,5,))

# %%
D.dtype
# Out:
# torch.int64

# %%
#castear los tensores

C + D.float()
# Out:
# tensor([[1., 0., 1., 1., 1.],
#         [0., 1., 1., 0., 1.],
#         [0., 1., 0., 0., 0.],
#         [1., 0., 1., 1., 0.],
#         [1., 0., 0., 0., 1.]])

# %%
#poner todos los tensores a un solo tipo

torch.set_default_tensor_type('torch.FloatTensor')

# %%
#ver si el tensor esta en la gpu o cpu 
C.device
# Out:
# device(type='cpu')

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') ##simplificar el envio de datos a gpu

# %%
x= torch.randn(3,5) #cpu
y= torch.ones_like(x, device=device)# gpu

# %%
x= x.to(device) #mandar tensores a gpu

# %%
z = x + y

# %%
print(z)
# Out:
# tensor([[ 1.4750,  0.5584,  2.7375,  0.4865,  0.5176],
#         [ 0.6326,  1.8815,  1.9502, -0.5885,  3.3338],
#         [ 2.8137,  1.5262, -0.9900,  0.9469,  1.5993]], device='cuda:0')

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from torchvision import datasets

# %%
dir(datasets)
# Out:
# ['CIFAR10',
#  'CIFAR100',
#  'CLEVRClassification',
#  'CREStereo',
#  'Caltech101',
#  'Caltech256',
#  'CarlaStereo',
#  'CelebA',
#  'Cityscapes',
#  'CocoCaptions',
#  'CocoDetection',
#  'Country211',
#  'DTD',
#  'DatasetFolder',
#  'EMNIST',
#  'ETH3DStereo',
#  'EuroSAT',
#  'FER2013',
#  'FGVCAircraft',
#  'FakeData',
#  'FallingThingsStereo',
#  'FashionMNIST',
#  'Flickr30k',
#  'Flickr8k',
#  'Flowers102',
#  'FlyingChairs',
#  'FlyingThings3D',
#  'Food101',
#  'GTSRB',
#  'HD1K',
#  'HMDB51',
#  'INaturalist',
#  'ImageFolder',
#  'ImageNet',
#  'InStereo2k',
#  'KMNIST',
#  'Kinetics',
#  'Kitti',
#  'Kitti2012Stereo',
#  'Kitti2015Stereo',
#  'KittiFlow',
#  'LFWPairs',
#  'LFWPeople',
#  'LSUN',
#  'LSUNClass',
#  'MNIST',
#  'Middlebury2014Stereo',
#  'Omniglot',
#  'OxfordIIITPet',
#  'PCAM',
#  'PhotoTour',
#  'Places365',
#  'QMNIST',
#  'RenderedSST2',
#  'SBDataset',
#  'SBU',
#  'SEMEION',
#  'STL10',
#  'SUN397',
#  'SVHN',
#  'SceneFlowStereo',
# ...

# %%
cifar=datasets.CIFAR10('/gdrive/My Drive/dl-pytorch/datasets',download=True)
# Out:
# ...
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting /gdrive/My Drive/dl-pytorch/datasets/cifar-10-python.tar.gz to /gdrive/My Drive/dl-pytorch/datasets

# %%
len(cifar)
# Out:
# 50000

# %%
data= torch.Tensor(cifar.data)

# %%
data.size()
## sintaxis primera dimension para la cantidad de imagenes en este caso 50000
## los dos siguientes osn las dimensiones de las imagenes  en este caso 32 x 32
## y el ultimo campo son los tres canales para imagenes de colores (r,g,b)
# Out:
# torch.Size([50000, 32, 32, 3])

# %%
2
